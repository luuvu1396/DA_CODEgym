# %% [markdown]
# <a href="https://colab.research.google.com/github/luuvu1396/DA_CODEgym/blob/main/%5BTh%E1%BB%B1c_h%C3%A0nh%5D_%C4%90%E1%BB%8Dc_d%E1%BB%AF_li%E1%BB%87u_v%C3%A0o_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/AmesHousing-TEST.csv')
df.head()
# Out:
#    Unnamed: 0  Order        PID  MS SubClass MS Zoning  Lot Frontage  \
# 0           0      1  526301100           20        RL         141.0
# 1           1      2  526350040           20        RH          80.0
# 2           2      3  526351010           20        RL          81.0
# 3           3      4  526353030           20        RL          93.0
# 4           4      5  527105010           60        RL          74.0
#
#    Lot Area Street Alley Lot Shape  ... Pool Area Pool QC  Fence Misc Feature  \
# 0     31770   Pave   NaN       IR1  ...         0     NaN    NaN          NaN
# 1     11622   Pave   NaN       Reg  ...         0     NaN  MnPrv          NaN
# 2     14267   Pave   NaN       IR1  ...         0     NaN    NaN         Gar2
# 3     11160   Pave   NaN       Reg  ...         0     NaN    NaN          NaN
# 4     13830   Pave   NaN       IR1  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type Sale Condition  SalePrice
# ...

# %%
df=pd.read_excel('/content/AmesHousing-TEST.xlsx')
df.head()
# Out:
#    Unnamed: 0  Order        PID  MS SubClass MS Zoning  Lot Frontage  \
# 0           0      1  526301100           20        RL         141.0
# 1           1      2  526350040           20        RH          80.0
# 2           2      3  526351010           20        RL          81.0
# 3           3      4  526353030           20        RL          93.0
# 4           4      5  527105010           60        RL          74.0
#
#    Lot Area Street Alley Lot Shape  ... Pool Area Pool QC  Fence Misc Feature  \
# 0     31770   Pave   NaN       IR1  ...         0     NaN    NaN          NaN
# 1     11622   Pave   NaN       Reg  ...         0     NaN  MnPrv          NaN
# 2     14267   Pave   NaN       IR1  ...         0     NaN    NaN         Gar2
# 3     11160   Pave   NaN       Reg  ...         0     NaN    NaN          NaN
# 4     13830   Pave   NaN       IR1  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type Sale Condition  SalePrice
# ...

# %%
df = pd.read_json('/content/AmesHousing-JSON.json')
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0  None       IR1          Lvl  ...         0    None   None         None
# 1  None       Reg          Lvl  ...         0    None  MnPrv         None
# 2  None       IR1          Lvl  ...         0    None   None         Gar2
# 3  None       Reg          Lvl  ...         0    None   None         None
# 4  None       IR1          Lvl  ...         0    None  MnPrv         None
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
df=pd.read_hdf('/content/AmesHousing-H5.h5')
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
df = pd.read_html('/content/AmesHousing-HTML.html')
df[0].head()
# Out:
#    Unnamed: 0  Order        PID  MS SubClass MS Zoning  Lot Frontage  \
# 0           0      1  526301100           20        RL         141.0
# 1           1      2  526350040           20        RH          80.0
# 2           2      3  526351010           20        RL          81.0
# 3           3      4  526353030           20        RL          93.0
# 4           4      5  527105010           60        RL          74.0
#
#    Lot Area Street Alley Lot Shape  ... Pool Area Pool QC  Fence Misc Feature  \
# 0     31770   Pave   NaN       IR1  ...         0     NaN    NaN          NaN
# 1     11622   Pave   NaN       Reg  ...         0     NaN  MnPrv          NaN
# 2     14267   Pave   NaN       IR1  ...         0     NaN    NaN         Gar2
# 3     11160   Pave   NaN       Reg  ...         0     NaN    NaN          NaN
# 4     13830   Pave   NaN       IR1  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type Sale Condition  SalePrice
# ...
